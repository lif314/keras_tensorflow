# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn import preprocessing
import numpy as np

a = np.array([
    [10,2,7,4],
    [12,56,67,12],
    [122,45,56,89]], dtype=np.float64)

print(a)

print(preprocessing.scale(a)) # 标准化
# Out:
# [[ 10.   2.   7.   4.]
#  [ 12.  56.  67.  12.]
#  [122.  45.  56.  89.]]
# [[-0.72612938 -1.38769813 -1.39309212 -0.80890976]
#  [-0.68791204  0.92990081  0.90742698 -0.60015885]
#  [ 1.41404142  0.45779732  0.48566514  1.40906861]]

# %%
from sklearn import preprocessing
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.svm import SVC  # 支持向量机
import matplotlib.pyplot as plt

# %%
# 生成分类的数据
X, y = make_classification(n_samples=300, n_features=2, n_redundant=0, n_informative=2,
                          random_state=22, n_clusters_per_class=1, scale=100)
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

clf = SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(clf.score(X_test, y_test))
# Out:
# 0.9555555555555556

# %%
# 数据标准化
X = preprocessing.scale(X)
y = preprocessing.scale(y)  # 也可以使用 minmax_scale(y, feature_range(-1,1)) 标准的范围
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

clf = SVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(clf.score(X_test, y_test))
# Out:
# 0.9222222222222223
